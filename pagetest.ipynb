# %%
from lstore.page import Page
page1 = Page()
print(page1)
print("num_records:", page1.num_records)
print(type(page1.num_records))
print("data:", page1.data)
print(type(page1.data))
print("length of data:", len(page1.data))
print(type(len(page1.data)))
# Out:
# ...
# num_records: 0
# <class 'int'>
# ...

# %% [markdown]
# Test page capacity using num_records

# %%
page1.num_records = 4090
print(page1.num_records)
while page1.num_records < 4100:
    if page1.has_capacity:
        print(f"page1 still has capacity ({page1.num_records})")
    else:
        print(f"page1 does not have capacity ({page1.num_records})")
    page1.num_records += 1
# Out:
# 4090
# page1 still has capacity (4090)
# page1 still has capacity (4091)
# page1 still has capacity (4092)
# page1 still has capacity (4093)
# page1 still has capacity (4094)
# page1 still has capacity (4095)
# page1 still has capacity (4096)
# page1 still has capacity (4097)
# page1 still has capacity (4098)
# page1 still has capacity (4099)
